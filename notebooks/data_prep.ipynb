# %%
import os
import json
import pandas as pd

DATA_PATH = '../data/'

# %%
# reads data from reports in train and test in storage
reports = pd.read_csv(os.path.join(DATA_PATH, 'indiana_reports.csv'))
print(reports.shape)
ids = pd.read_csv(os.path.join(DATA_PATH, 'indiana_projections.csv'))
print(ids.shape)

# merging 
df = pd.merge(reports, ids, on=['uid'], how='left')

df['uid'] = df['uid'].astype(int)
df['im_1'] = df['filename'].apply(lambda x: x.split('-')[1])
df['im_2'] = df['filename'].apply(lambda x: x.split('-')[2][:4])


df.sort_values('filename', ascending=False).head()
df.sort_values('uid', ascending=False).head()
# Out:
# (3851, 8)
# (7466, 3)
#        uid                                               MeSH  \
# 7464  3999                                             normal
# 7465  3999                                             normal
# 7463  3998                                             normal
# 7462  3998                                             normal
# 7461  3997  Opacity/lung/upper lobe/right/round/small;Gran...
#
#                Problems                                              image  \
# 7464             normal              CHEST PA and LATERAL: on XXXX, XXXX.
# 7465             normal              CHEST PA and LATERAL: on XXXX, XXXX.
# 7463             normal   PA and lateral chest XXXX, XXXX XXXX comparis...
# 7462             normal   PA and lateral chest XXXX, XXXX XXXX comparis...
# 7461  Opacity;Granuloma                PA and lateral views of the chest.
#
#                                              indication  \
# 7464  This is a XXXX-year-old female patient with sh...
# 7465  This is a XXXX-year-old female patient with sh...
# 7463                          tuberculosis positive PPD
# 7462                          tuberculosis positive PPD
# 7461              XXXX-year-old male with positive PPD.
#
#                      comparison  \
# 7464  Chest x-XXXX, XXXX, XXXX.
# 7465  Chest x-XXXX, XXXX, XXXX.
# 7463                        NaN
# 7462                        NaN
# 7461            None available.
#
#                                                findings  \
# 7464                                                NaN
# 7465                                                NaN
# 7463                                                NaN
# 7462                                                NaN
# 7461  Heart size within normal limits. Small, nodula...
#
#                                              impression  \
# 7464  The cardiac silhouette is normal in size and c...
# 7465  The cardiac silhouette is normal in size and c...
# 7463      Heart size is normal and the lungs are clear.
# 7462      Heart size is normal and the lungs are clear.
# 7461      No acute findings, no evidence for active TB.
#
#                        filename projection  im_1  im_2
# 7464  3999_IM-2049-1001.dcm.png    Frontal  2049  1001
# 7465  3999_IM-2049-2001.dcm.png    Lateral  2049  2001
# 7463  3998_IM-2048-1002.dcm.png    Lateral  2048  1002
# 7462  3998_IM-2048-1001.dcm.png    Frontal  2048  1001
# 7461  3997_IM-2048-1002.dcm.png    Lateral  2048  1002

# %%
# adding annotations provided
annotations_json = json.load(open(os.path.join(DATA_PATH, 'annotation_quiz_all.json')))
annotations_train = pd.DataFrame.from_records(annotations_json['train'])
print(annotations_train.shape)
annotations_test = pd.DataFrame.from_records(annotations_json['test'])
print(annotations_test.shape)
annotations_val = pd.DataFrame.from_records(annotations_json['val'])
print(annotations_val.shape)
annotations = pd.concat([annotations_train, annotations_test, annotations_val], axis=0)
annotations = annotations.rename(columns={'report':'annotation'})
print(annotations.shape)

annotations['uid'] = annotations['id'].apply(lambda x: x.split('_')[0].replace('CXR','')).astype(int)
annotations['im_1'] = annotations['id'].apply(lambda x: x.split("IM-")[-1][:4])

annotations.head()
# Out:
# (2069, 3)
# (590, 3)
# (296, 3)
# (2955, 4)
#                 id  \
# 0  CXR2384_IM-0942
# 1  CXR2926_IM-1328
# 2  CXR1451_IM-0291
# 3  CXR2887_IM-1289
# 4  CXR1647_IM-0424
#
#                                                                                                                                                                                                 annotation  \
# 0  {'bone': 'Degenerative changes are present in the spine.', 'heart': 'Heart size and pulmonary vascularity appear within normal limits.', 'lung': 'Lungs are free of focal airspace disease. No pneum...
# 1  {'bone': 'Bony structures are intact.', 'heart': 'Cardiac contours are within normal limits.', 'lung': 'Lungs are clear.', 'mediastinal': 'Mediastinal contours are within normal limits.', 'others'...
# 2  {'bone': '', 'heart': 'Heart size normal.', 'lung': 'Left lower lobe calcified granuloma. No pleural effusion or pneumothorax. Mild medial right atelectasis. Mild emphysema.', 'mediastinal': '', '...
# 3  {'bone': 'Displaced fracture of the mid one-third of the right clavicle.', 'heart': 'Cardiac contours are within normal limits.', 'lung': 'There are a few opacities in the lung bases bilaterally. ...
# 4  {'bone': 'Visualized osseous structures of the thorax are without acute abnormality.', 'heart': 'Cardiac contours are within normal limits.', 'lung': 'The lungs are clear bilaterally. No evidence ...
#
#    split original_report   uid  im_1
# 0  train             NaN  2384  0942
# 1  train             NaN  2926  1328
# 2  train             NaN  1451  0291
# 3  train             NaN  2887  1289
# 4  train             NaN  1647  0424

# %%
# overall dataset
df = pd.merge(df, annotations, how='left', on=['uid', 'im_1'], suffixes=('', '_annotated'))
print(df.shape)
# Out:
# (7466, 16)

# %%
df.head()
# Out:
#    uid                                               MeSH  \
# 0    1                                             normal
# 1    1                                             normal
# 2    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 3    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 4    3                                             normal
#
#                         Problems                                image  \
# 0                         normal            Xray Chest PA and Lateral
# 1                         normal            Xray Chest PA and Lateral
# 2  Cardiomegaly;Pulmonary Artery  Chest, 2 views, frontal and lateral
# 3  Cardiomegaly;Pulmonary Artery  Chest, 2 views, frontal and lateral
# 4                         normal            Xray Chest PA and Lateral
#
#                                                                                                                                    indication  \
# 0                                                                                                                            Positive TB test
# 1                                                                                                                            Positive TB test
# 2                                                                                                                    Preop bariatric surgery.
# 3                                                                                                                    Preop bariatric surgery.
# 4  rib pain after a XXXX, XXXX XXXX steps this XXXX. Pain to R back, R elbow and R rib XXXX, no previous heart or lung hx, non-XXXX, no hx ca
#
#   comparison  \
# 0      None.
# 1      None.
# 2      None.
# 3      None.
# 4        NaN
#
#                                                                                                                                                                                                   findings  \
# 0  The cardiac silhouette and mediastinum size are within normal limits. There is no pulmonary edema. There is no focal consolidation. There are no XXXX of a pleural effusion. There is no evidence of...
# 1  The cardiac silhouette and mediastinum size are within normal limits. There is no pulmonary edema. There is no focal consolidation. There are no XXXX of a pleural effusion. There is no evidence of...
# 2                                                                                     Borderline cardiomegaly. Midline sternotomy XXXX. Enlarged pulmonary arteries. Clear lungs. Inferior XXXX XXXX XXXX.
# 3                                                                                     Borderline cardiomegaly. Midline sternotomy XXXX. Enlarged pulmonary arteries. Clear lungs. Inferior XXXX XXXX XXXX.
# 4                                                                                                                                                                                                      NaN
#
#                                                                                                                                                                                             impression  \
# 0                                                                                                                                                                                 Normal chest x-XXXX.
# 1                                                                                                                                                                                 Normal chest x-XXXX.
# 2                                                                                                                                                                         No acute pulmonary findings.
# 3                                                                                                                                                                         No acute pulmonary findings.
# 4  No displaced rib fractures, pneumothorax, or pleural effusion identified. Well-expanded and clear lungs. Mediastinal contour within normal limits. No acute cardiopulmonary abnormality identified.
#
#                  filename projection  im_1  im_2              id  \
# 0  1_IM-0001-4001.dcm.png    Frontal  0001  4001  CXR1_1_IM-0001
# 1  1_IM-0001-3001.dcm.png    Lateral  0001  3001  CXR1_1_IM-0001
# 2  2_IM-0652-1001.dcm.png    Frontal  0652  1001    CXR2_IM-0652
# 3  2_IM-0652-2001.dcm.png    Lateral  0652  2001    CXR2_IM-0652
# 4  3_IM-1384-1001.dcm.png    Frontal  1384  1001             NaN
#
#                                                                                                                                                                                                 annotation  \
# 0  {'bone': '', 'heart': 'Cardiac silhouette within normal limits.', 'lung': 'No pulmonary edema. No focal consolidation. No evidence of pneumothorax.', 'mediastinal': 'Mediastinum size within normal...
# 1  {'bone': '', 'heart': 'Cardiac silhouette within normal limits.', 'lung': 'No pulmonary edema. No focal consolidation. No evidence of pneumothorax.', 'mediastinal': 'Mediastinum size within normal...
# 2                       {'bone': 'Midline sternotomy.', 'heart': 'Borderline cardiomegaly.', 'lung': 'Clear lungs. Enlarged pulmonary arteries.', 'mediastinal': '', 'others': 'Inferior XXXX XXXX XXXX.'}
# 3                       {'bone': 'Midline sternotomy.', 'heart': 'Borderline cardiomegaly.', 'lung': 'Clear lungs. Enlarged pulmonary arteries.', 'mediastinal': '', 'others': 'Inferior XXXX XXXX XXXX.'}
# 4                                                                                                                                                                                                      NaN
#
#    split original_report
# 0  train             NaN
# 1  train             NaN
# 2   test             NaN
# 3   test             NaN
# 4    NaN             NaN

# %%
df.isnull().sum()
# Out:
# uid                   0
# MeSH                  0
# Problems              0
# image                 0
# indication          159
# comparison         2260
# findings            997
# impression           52
# filename              0
# projection            0
# im_1                  0
# im_2                  0
# id                 1381
# annotation         1987
# split              1381
# original_report    6860
# dtype: int64

# %%
df[~df['original_report'].isnull()][['findings','original_report']].head(100)
# Out:
#                                                                                                                                                                                                      findings  \
# 6     There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that co...
# 7     There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that co...
# 46    Cardiomediastinal silhouette is within normal limits of size and appearance. The pulmonary vascularity is unremarkable. Lungs are expanded and clear of airspace disease. Negative for pneumothorax ...
# 47    Cardiomediastinal silhouette is within normal limits of size and appearance. The pulmonary vascularity is unremarkable. Lungs are expanded and clear of airspace disease. Negative for pneumothorax ...
# 50                                                                                                                                The cardiac contours are normal. The lungs are clear. Thoracic spondylosis.
# ...                                                                                                                                                                                                       ...
# 1574    Cardiomediastinal silhouette and pulmonary vasculature are within normal limits. Lungs are clear. No pneumothorax or pleural effusion. No radiodense foreign bodies noted. No acute osseous findings.
# 1575    Cardiomediastinal silhouette and pulmonary vasculature are within normal limits. Lungs are clear. No pneumothorax or pleural effusion. No radiodense foreign bodies noted. No acute osseous findings.
# 1600  Limited evaluation of the lateral view due to rotation and frontal view due to motion artifact. Stable mild cardiomegaly. Normal pulmonary vascularity. The lungs are clear. No focal consolidation,...
# 1601  Limited evaluation of the lateral view due to rotation and frontal view due to motion artifact. Stable mild cardiomegaly. Normal pulmonary vascularity. The lungs are clear. No focal consolidation,...
# 1608  Chronic increased interstitial markings without evidence of focal infiltrate. Bilateral apical pleural thickening. No pneumothorax. No pleural effusion. Stable heart size. Marked degenerative chan...
#
#                                                                                                                                                                                               original_report
# 6     There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that co...
# 7     There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that co...
# 46    Cardiomediastinal silhouette is within normal limits of size and appearance. The pulmonary vascularity is unremarkable. Lungs are expanded and clear of airspace disease. Negative for pneumothorax ...
# 47    Cardiomediastinal silhouette is within normal limits of size and appearance. The pulmonary vascularity is unremarkable. Lungs are expanded and clear of airspace disease. Negative for pneumothorax ...
# 50                                                                                                                                The cardiac contours are normal. The lungs are clear. Thoracic spondylosis.
# ...                                                                                                                                                                                                       ...
# 1574    Cardiomediastinal silhouette and pulmonary vasculature are within normal limits. Lungs are clear. No pneumothorax or pleural effusion. No radiodense foreign bodies noted. No acute osseous findings.
# 1575    Cardiomediastinal silhouette and pulmonary vasculature are within normal limits. Lungs are clear. No pneumothorax or pleural effusion. No radiodense foreign bodies noted. No acute osseous findings.
# 1600  Limited evaluation of the lateral view due to rotation and frontal view due to motion artifact. Stable mild cardiomegaly. Normal pulmonary vascularity. The lungs are clear. No focal consolidation,...
# 1601  Limited evaluation of the lateral view due to rotation and frontal view due to motion artifact. Stable mild cardiomegaly. Normal pulmonary vascularity. The lungs are clear. No focal consolidation,...
# 1608  Chronic increased interstitial markings without evidence of focal infiltrate. Bilateral apical pleural thickening. No pneumothorax. No pleural effusion. Stable heart size. Marked degenerative chan...
#
# [100 rows x 2 columns]

# %%
# filling nulls to get uniform 'original_report'
df['original_report'] = df['original_report'].fillna(df['findings'])

df.to_csv(os.path.join(DATA_PATH, 'data_prep.csv'), index=False)

# %%
df[~df['annotation'].isnull()][['annotation','original_report']]#.head(100)
# Out:
#                                                                                                                                                                                                    annotation  \
# 0     {'bone': '', 'heart': 'Cardiac silhouette within normal limits.', 'lung': 'No pulmonary edema. No focal consolidation. No evidence of pneumothorax.', 'mediastinal': 'Mediastinum size within normal...
# 1     {'bone': '', 'heart': 'Cardiac silhouette within normal limits.', 'lung': 'No pulmonary edema. No focal consolidation. No evidence of pneumothorax.', 'mediastinal': 'Mediastinum size within normal...
# 2                          {'bone': 'Midline sternotomy.', 'heart': 'Borderline cardiomegaly.', 'lung': 'Clear lungs. Enlarged pulmonary arteries.', 'mediastinal': '', 'others': 'Inferior XXXX XXXX XXXX.'}
# 3                          {'bone': 'Midline sternotomy.', 'heart': 'Borderline cardiomegaly.', 'lung': 'Clear lungs. Enlarged pulmonary arteries.', 'mediastinal': '', 'others': 'Inferior XXXX XXXX XXXX.'}
# 8     {'bone': 'Small T-spine osteophytes.', 'heart': 'Cardiac contours are within normal limits.', 'lung': 'There is no pneumothorax or pleural effusion. There are no focal areas of consolidation. Ther...
# ...                                                                                                                                                                                                       ...
# 7457  {'bone': 'No acute bony findings.', 'heart': 'Cardiomediastinal silhouette are within normal limits in size.', 'lung': 'Pulmonary vasculature are within normal limits in size. The lungs are mildly...
# 7458                                               {'bone': 'Endplate changes in the spine.', 'heart': 'Heart size is normal.', 'lung': 'Lungs are clear. No pneumothorax.', 'mediastinal': '', 'others': ''}
# 7459                                               {'bone': 'Endplate changes in the spine.', 'heart': 'Heart size is normal.', 'lung': 'Lungs are clear. No pneumothorax.', 'mediastinal': '', 'others': ''}
# 7460                      {'bone': '', 'heart': 'Heart size within normal limits.', 'lung': 'Small, nodular opacity in the right upper lobe. No pneumothorax or effusions.', 'mediastinal': '', 'others': ''}
# 7461                      {'bone': '', 'heart': 'Heart size within normal limits.', 'lung': 'Small, nodular opacity in the right upper lobe. No pneumothorax or effusions.', 'mediastinal': '', 'others': ''}
#
#                                                                                                                                                                                               original_report
# 0     The cardiac silhouette and mediastinum size are within normal limits. There is no pulmonary edema. There is no focal consolidation. There are no XXXX of a pleural effusion. There is no evidence of...
# 1     The cardiac silhouette and mediastinum size are within normal limits. There is no pulmonary edema. There is no focal consolidation. There are no XXXX of a pleural effusion. There is no evidence of...
# 2                                                                                        Borderline cardiomegaly. Midline sternotomy XXXX. Enlarged pulmonary arteries. Clear lungs. Inferior XXXX XXXX XXXX.
# 3                                                                                        Borderline cardiomegaly. Midline sternotomy XXXX. Enlarged pulmonary arteries. Clear lungs. Inferior XXXX XXXX XXXX.
# 8     The cardiomediastinal silhouette and pulmonary vasculature are within normal limits. There is no pneumothorax or pleural effusion. There are no focal areas of consolidation. Cholecystectomy clips ...
# ...                                                                                                                                                                                                       ...
# 7457  The cardiomediastinal silhouette and pulmonary vasculature are within normal limits in size. The lungs are mildly hyperinflated with flattening of the diaphragms and expansion of the retrosternal ...
# 7458                                                                                                     The lungs are clear. Heart size is normal. No pneumothorax. There are endplate changes in the spine.
# 7459                                                                                                     The lungs are clear. Heart size is normal. No pneumothorax. There are endplate changes in the spine.
# 7460        Heart size within normal limits. Small, nodular opacity in the right upper lobe. This does not look like an acute infiltrate, and more XXXX represents a granuloma. No pneumothorax or effusions.
# 7461        Heart size within normal limits. Small, nodular opacity in the right upper lobe. This does not look like an acute infiltrate, and more XXXX represents a granuloma. No pneumothorax or effusions.
#
# [5479 rows x 2 columns]

# %%
df = pd.read_csv(os.path.join(DATA_PATH, 'data_prep.csv'))

# %%
df[df['split']=='train']
# Out:
#        uid                                               MeSH  \
# 0        1                                             normal
# 1        1                                             normal
# 8        5  Osteophyte/thoracic vertebrae/multiple/small;T...
# 9        5  Osteophyte/thoracic vertebrae/multiple/small;T...
# 10       6                                             normal
# ...    ...                                                ...
# 7455  3994  Cardiomegaly/mild;Pulmonary Congestion;Heart F...
# 7456  3995  Lung/hyperdistention/mild;Diaphragm/bilateral/...
# 7457  3995  Lung/hyperdistention/mild;Diaphragm/bilateral/...
# 7458  3996                                 Spine/degenerative
# 7459  3996                                 Spine/degenerative
#
#                                                Problems  \
# 0                                                normal
# 1                                                normal
# 8                            Osteophyte;Thickening;Lung
# 9                            Osteophyte;Thickening;Lung
# 10                                               normal
# ...                                                 ...
# 7455    Cardiomegaly;Pulmonary Congestion;Heart Failure
# 7456  Lung;Diaphragm;Cicatrix;Pulmonary Atelectasis;...
# 7457  Lung;Diaphragm;Cicatrix;Pulmonary Atelectasis;...
# 7458                                              Spine
# 7459                                              Spine
#
#                                                   image  \
# 0                             Xray Chest PA and Lateral
# 1                             Xray Chest PA and Lateral
# 8                             Xray Chest PA and Lateral
# 9                             Xray Chest PA and Lateral
# 10            PA and Lateral Chest. XXXX, XXXX at XXXX
# ...                                                 ...
# 7455  2 view ( PA and lateral) chest radiograph date...
# 7456                          Xray Chest PA and Lateral
# 7457                          Xray Chest PA and Lateral
# 7458                          Xray Chest PA and Lateral
# 7459                          Xray Chest PA and Lateral
#
#                                              indication  \
# 0                                      Positive TB test
# 1                                      Positive TB test
# 8                           Chest and nasal congestion.
# 9                           Chest and nasal congestion.
# 10                               Evaluate for infection
# ...                                                 ...
# 7455  XXXX-year-old male with chest pain, positive t...
# 7456       Nausea, vomiting x2 weeks. Dialysis patient.
# 7457       Nausea, vomiting x2 weeks. Dialysis patient.
# 7458                                                NaN
# 7459                                                NaN
#
#                             comparison  \
# 0                                None.
# 1                                None.
# 8                                  NaN
# 9                                  NaN
# 10                          XXXX, XXXX
# ...                                ...
# 7455  Portable chest x-XXXX XXXX, XXXX
# 7456                       XXXX, XXXX.
# 7457                       XXXX, XXXX.
# 7458                             None.
# 7459                             None.
#
#                                                findings  \
# 0     The cardiac silhouette and mediastinum size ar...
# 1     The cardiac silhouette and mediastinum size ar...
# 8     The cardiomediastinal silhouette and pulmonary...
# 9     The cardiomediastinal silhouette and pulmonary...
# 10    Heart size and mediastinal contour are within ...
# ...                                                 ...
# 7455  Similar mild cardiomegaly. Of the pulmonary va...
# 7456  The cardiomediastinal silhouette and pulmonary...
# 7457  The cardiomediastinal silhouette and pulmonary...
# 7458  The lungs are clear. Heart size is normal. No ...
# 7459  The lungs are clear. Heart size is normal. No ...
#
#                                              impression  \
# 0                                  Normal chest x-XXXX.
# 1                                  Normal chest x-XXXX.
# 8                 No acute cardiopulmonary abnormality.
# 9                 No acute cardiopulmonary abnormality.
# 10                   No acute cardiopulmonary findings.
# ...                                                 ...
# 7455      Mild cardiomegaly with XXXX of early failure.
# 7456  1. Interval resolution of bibasilar airspace d...
# 7457  1. Interval resolution of bibasilar airspace d...
# 7458  Clear lungs. No acute cardiopulmonary abnormal...
# 7459  Clear lungs. No acute cardiopulmonary abnormal...
#
#                        filename projection  im_1  im_2               id  \
# 0        1_IM-0001-4001.dcm.png    Frontal     1  4001   CXR1_1_IM-0001
# 1        1_IM-0001-3001.dcm.png    Lateral     1  3001   CXR1_1_IM-0001
# 8     5_IM-2117-1003002.dcm.png    Frontal  2117  1003     CXR5_IM-2117
# 9     5_IM-2117-1004003.dcm.png    Lateral  2117  1004     CXR5_IM-2117
# 10       6_IM-2192-1001.dcm.png    Frontal  2192  1001     CXR6_IM-2192
# ...                         ...        ...   ...   ...              ...
# 7455  3994_IM-2045-1001.dcm.png    Lateral  2045  1001  CXR3994_IM-2045
# 7456  3995_IM-2046-1001.dcm.png    Frontal  2046  1001  CXR3995_IM-2046
# 7457  3995_IM-2046-2001.dcm.png    Lateral  2046  2001  CXR3995_IM-2046
# 7458  3996_IM-2047-1001.dcm.png    Frontal  2047  1001  CXR3996_IM-2047
# 7459  3996_IM-2047-3001.dcm.png    Lateral  2047  3001  CXR3996_IM-2047
#
#                                              annotation  split  \
# 0     {'bone': '', 'heart': 'Cardiac silhouette with...  train
# 1     {'bone': '', 'heart': 'Cardiac silhouette with...  train
# 8     {'bone': 'Small T-spine osteophytes.', 'heart'...  train
# 9     {'bone': 'Small T-spine osteophytes.', 'heart'...  train
# 10    {'bone': 'Mild degenerative change of the thor...  train
# ...                                                 ...    ...
# 7455  {'bone': 'No acute bony abnormality.', 'heart'...  train
# 7456  {'bone': 'No acute bony findings.', 'heart': '...  train
# 7457  {'bone': 'No acute bony findings.', 'heart': '...  train
# 7458  {'bone': 'Endplate changes in the spine.', 'he...  train
# 7459  {'bone': 'Endplate changes in the spine.', 'he...  train
#
#                                         original_report
# 0     The cardiac silhouette and mediastinum size ar...
# 1     The cardiac silhouette and mediastinum size ar...
# 8     The cardiomediastinal silhouette and pulmonary...
# 9     The cardiomediastinal silhouette and pulmonary...
# 10    Heart size and mediastinal contour are within ...
# ...                                                 ...
# 7455  Similar mild cardiomegaly. Of the pulmonary va...
# 7456  The cardiomediastinal silhouette and pulmonary...
# 7457  The cardiomediastinal silhouette and pulmonary...
# 7458  The lungs are clear. Heart size is normal. No ...
# 7459  The lungs are clear. Heart size is normal. No ...
#
# [4258 rows x 16 columns]

# %%
df[df['split']=='test']
# Out:
#        uid                                               MeSH  \
# 2        2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 3        2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 22      12                                             normal
# 23      12                                             normal
# 24      13                          Cardiac Shadow/borderline
# ...    ...                                                ...
# 7449  3991                     Spondylosis/thoracic vertebrae
# 7452  3993          Cardiomegaly/mild;Diaphragm/left/elevated
# 7453  3993          Cardiomegaly/mild;Diaphragm/left/elevated
# 7460  3997  Opacity/lung/upper lobe/right/round/small;Gran...
# 7461  3997  Opacity/lung/upper lobe/right/round/small;Gran...
#
#                            Problems  \
# 2     Cardiomegaly;Pulmonary Artery
# 3     Cardiomegaly;Pulmonary Artery
# 22                           normal
# 23                           normal
# 24                   Cardiac Shadow
# ...                             ...
# 7449                    Spondylosis
# 7452         Cardiomegaly;Diaphragm
# 7453         Cardiomegaly;Diaphragm
# 7460              Opacity;Granuloma
# 7461              Opacity;Granuloma
#
#                                                   image  \
# 2                   Chest, 2 views, frontal and lateral
# 3                   Chest, 2 views, frontal and lateral
# 22    PA and lateral chest radiograph (2 views) (2 i...
# 23    PA and lateral chest radiograph (2 views) (2 i...
# 24    PA and lateral chest radiograph (2 views) (2 i...
# ...                                                 ...
# 7449                          Xray Chest PA and Lateral
# 7452                          CHEST 2V FRONTAL/LATERAL
# 7453                          CHEST 2V FRONTAL/LATERAL
# 7460                PA and lateral views of the chest.
# 7461                PA and lateral views of the chest.
#
#                                  indication  \
# 2                  Preop bariatric surgery.
# 3                  Preop bariatric surgery.
# 22                                     XXXX
# 23                                     XXXX
# 24                              Chest pain.
# ...                                     ...
# 7449                Preop bariatric surgery
# 7452                                  Edema
# 7453                                  Edema
# 7460  XXXX-year-old male with positive PPD.
# 7461  XXXX-year-old male with positive PPD.
#
#                              comparison  \
# 2                                 None.
# 3                                 None.
# 22                                  NaN
# 23                                  NaN
# 24    Chest radiograph from XXXX, XXXX.
# ...                                 ...
# 7449                              None.
# 7452                                NaN
# 7453                                NaN
# 7460                    None available.
# 7461                    None available.
#
#                                                findings  \
# 2     Borderline cardiomegaly. Midline sternotomy XX...
# 3     Borderline cardiomegaly. Midline sternotomy XX...
# 22    Lungs are clear bilaterally. Cardiac and media...
# 23    Lungs are clear bilaterally. Cardiac and media...
# 24    The cardiac silhouette is borderline enlarged....
# ...                                                 ...
# 7449  The cardiac contours are normal. The lungs are...
# 7452  The heart is mildly enlarged. Left hemidiaphra...
# 7453  The heart is mildly enlarged. Left hemidiaphra...
# 7460  Heart size within normal limits. Small, nodula...
# 7461  Heart size within normal limits. Small, nodula...
#
#                                              impression  \
# 2                          No acute pulmonary findings.
# 3                          No acute pulmonary findings.
# 22                No acute cardiopulmonary abnormality.
# 23                No acute cardiopulmonary abnormality.
# 24    Borderline enlargement of the cardiac silhouet...
# ...                                                 ...
# 7449                    No acute preoperative findings.
# 7452     Borderline cardiomegaly without acute disease.
# 7453     Borderline cardiomegaly without acute disease.
# 7460      No acute findings, no evidence for active TB.
# 7461      No acute findings, no evidence for active TB.
#
#                        filename projection  im_1  im_2               id  \
# 2        2_IM-0652-1001.dcm.png    Frontal   652  1001     CXR2_IM-0652
# 3        2_IM-0652-2001.dcm.png    Lateral   652  2001     CXR2_IM-0652
# 22      12_IM-0133-1001.dcm.png    Frontal   133  1001    CXR12_IM-0133
# 23      12_IM-0133-2001.dcm.png    Lateral   133  2001    CXR12_IM-0133
# 24      13_IM-0198-1001.dcm.png    Frontal   198  1001    CXR13_IM-0198
# ...                         ...        ...   ...   ...              ...
# 7449  3991_IM-2044-2001.dcm.png    Lateral  2044  2001  CXR3991_IM-2044
# 7452  3993_IM-2044-1001.dcm.png    Frontal  2044  1001  CXR3993_IM-2044
# 7453  3993_IM-2044-1002.dcm.png    Lateral  2044  1002  CXR3993_IM-2044
# 7460  3997_IM-2048-1001.dcm.png    Frontal  2048  1001  CXR3997_IM-2048
# 7461  3997_IM-2048-1002.dcm.png    Lateral  2048  1002  CXR3997_IM-2048
#
#                                              annotation split  \
# 2     {'bone': 'Midline sternotomy.', 'heart': 'Bord...  test
# 3     {'bone': 'Midline sternotomy.', 'heart': 'Bord...  test
# 22    {'bone': 'No acute bony abnormality.', 'heart'...  test
# 23    {'bone': 'No acute bony abnormality.', 'heart'...  test
# 24    {'bone': '', 'heart': 'Cardiac silhouette is b...  test
# ...                                                 ...   ...
# 7449  {'bone': 'Thoracic spondylosis.', 'heart': 'Th...  test
# 7452  {'bone': '', 'heart': 'Mildly enlarged.', 'lun...  test
# 7453  {'bone': '', 'heart': 'Mildly enlarged.', 'lun...  test
# 7460  {'bone': '', 'heart': 'Heart size within norma...  test
# 7461  {'bone': '', 'heart': 'Heart size within norma...  test
#
#                                         original_report
# 2     Borderline cardiomegaly. Midline sternotomy XX...
# 3     Borderline cardiomegaly. Midline sternotomy XX...
# 22    Lungs are clear bilaterally. Cardiac and media...
# 23    Lungs are clear bilaterally. Cardiac and media...
# 24    The cardiac silhouette is borderline enlarged....
# ...                                                 ...
# 7449  The cardiac contours are normal. The lungs are...
# 7452  The heart is mildly enlarged. Left hemidiaphra...
# 7453  The heart is mildly enlarged. Left hemidiaphra...
# 7460  Heart size within normal limits. Small, nodula...
# 7461  Heart size within normal limits. Small, nodula...
#
# [1221 rows x 16 columns]

# %%
df[df['split']=='val']
# Out:
#        uid                                               MeSH  \
# 6        4  Pulmonary Disease, Chronic Obstructive;Bullous...
# 7        4  Pulmonary Disease, Chronic Obstructive;Bullous...
# 46      24                                             normal
# 47      24                                             normal
# 50      26                     Spondylosis/thoracic vertebrae
# ...    ...                                                ...
# 7360  3947                         Catheters, Indwelling/left
# 7383  3959                                        No Indexing
# 7384  3959                                        No Indexing
# 7415  3974  Lung/hyperdistention;Pulmonary Emphysema;Airsp...
# 7416  3974  Lung/hyperdistention;Pulmonary Emphysema;Airsp...
#
#                                                Problems  \
# 6     Pulmonary Disease, Chronic Obstructive;Bullous...
# 7     Pulmonary Disease, Chronic Obstructive;Bullous...
# 46                                               normal
# 47                                               normal
# 50                                          Spondylosis
# ...                                                 ...
# 7360                              Catheters, Indwelling
# 7383                                        No Indexing
# 7384                                        No Indexing
# 7415    Lung;Pulmonary Emphysema;Airspace Disease;Spine
# 7416    Lung;Pulmonary Emphysema;Airspace Disease;Spine
#
#                                                   image  \
# 6     PA and lateral views of the chest XXXX, XXXX a...
# 7     PA and lateral views of the chest XXXX, XXXX a...
# 46    PA AND LATERAL VIEWS OF THE CHEST dated XXXX X...
# 47    PA AND LATERAL VIEWS OF THE CHEST dated XXXX X...
# 50                  Chest, 2 views, frontal and lateral
# ...                                                 ...
# 7360                          Xray Chest PA and Lateral
# 7383                          Xray Chest PA and Lateral
# 7384                          Xray Chest PA and Lateral
# 7415                   PA and lateral chest x-XXXX XXXX
# 7416                   PA and lateral chest x-XXXX XXXX
#
#                                              indication  \
# 6                         XXXX-year-old XXXX with XXXX.
# 7                         XXXX-year-old XXXX with XXXX.
# 46                                        XXXX, dyspnea
# 47                                        XXXX, dyspnea
# 50                                                 XXXX
# ...                                                 ...
# 7360  Preprocedure evaluation prior to bone marrow t...
# 7383                XXXX S/P XXXX XXXX. Aortic stenosis
# 7384                XXXX S/P XXXX XXXX. Aortic stenosis
# 7415                                               XXXX
# 7416                                               XXXX
#
#                      comparison  \
# 6                None available
# 7                None available
# 46                        None.
# 47                        None.
# 50                        None.
# ...                         ...
# 7360                        NaN
# 7383       Chest 2 views. XXXX.
# 7384       Chest 2 views. XXXX.
# 7415  None available for review
# 7416  None available for review
#
#                                                findings  \
# 6     There are diffuse bilateral interstitial and a...
# 7     There are diffuse bilateral interstitial and a...
# 46    Cardiomediastinal silhouette is within normal ...
# 47    Cardiomediastinal silhouette is within normal ...
# 50    The cardiac contours are normal. The lungs are...
# ...                                                 ...
# 7360  The lungs appear clear. There are no suspiciou...
# 7383  The lungs are clear. Heart size is normal. No ...
# 7384  The lungs are clear. Heart size is normal. No ...
# 7415  The lungs are hyperexpanded consistent with em...
# 7416  The lungs are hyperexpanded consistent with em...
#
#                                              impression  \
# 6     1. Bullous emphysema and interstitial fibrosis...
# 7     1. Bullous emphysema and interstitial fibrosis...
# 46                No acute cardiopulmonary abnormality.
# 47                No acute cardiopulmonary abnormality.
# 50                                    No acute process.
# ...                                                 ...
# 7360                  No acute cardiopulmonary disease.
# 7383  Clear lungs. No acute cardiopulmonary abnormal...
# 7384  Clear lungs. No acute cardiopulmonary abnormal...
# 7415  1. Hyperexpanded lungs suggesting emphysema. 2...
# 7416  1. Hyperexpanded lungs suggesting emphysema. 2...
#
#                        filename projection  im_1  im_2               id  \
# 6        4_IM-2050-1001.dcm.png    Frontal  2050  1001     CXR4_IM-2050
# 7        4_IM-2050-2001.dcm.png    Lateral  2050  2001     CXR4_IM-2050
# 46      24_IM-0949-1001.dcm.png    Frontal   949  1001    CXR24_IM-0949
# 47      24_IM-0949-2001.dcm.png    Lateral   949  2001    CXR24_IM-0949
# 50      26_IM-1090-1001.dcm.png    Frontal  1090  1001    CXR26_IM-1090
# ...                         ...        ...   ...   ...              ...
# 7360  3947_IM-2016-2001.dcm.png    Lateral  2016  2001  CXR3947_IM-2016
# 7383  3959_IM-2023-1001.dcm.png    Frontal  2023  1001  CXR3959_IM-2023
# 7384  3959_IM-2023-3001.dcm.png    Lateral  2023  3001  CXR3959_IM-2023
# 7415  3974_IM-2034-2002.dcm.png    Frontal  2034  2002  CXR3974_IM-2034
# 7416  3974_IM-2034-3003.dcm.png    Lateral  2034  3003  CXR3974_IM-2034
#
#      annotation split                                    original_report
# 6           NaN   val  There are diffuse bilateral interstitial and a...
# 7           NaN   val  There are diffuse bilateral interstitial and a...
# 46          NaN   val  Cardiomediastinal silhouette is within normal ...
# 47          NaN   val  Cardiomediastinal silhouette is within normal ...
# 50          NaN   val  The cardiac contours are normal. The lungs are...
# ...         ...   ...                                                ...
# 7360        NaN   val  The lungs appear clear. There are no suspiciou...
# 7383        NaN   val  The lungs are clear. Heart size is normal. No ...
# 7384        NaN   val  The lungs are clear. Heart size is normal. No ...
# 7415        NaN   val  The lungs are hyperexpanded consistent with em...
# 7416        NaN   val  The lungs are hyperexpanded consistent with em...
#
# [606 rows x 16 columns]

# %%
df_train = pd.read_csv(os.path.join(DATA_PATH, 'reports_annotations_train.csv'))

# %%
df_train
# Out:
#     uid                                               MeSH  \
# 0  2349                                             normal
# 1  2949  Calcified Granuloma/lung/scattered/multiple;No...
# 2  2511  Sutures/lung/upper lobe/left;Cicatrix/costophr...
# 3  3363  Opacity/lung/base/bilateral/multiple;Foreign B...
# 4  2677  Aorta, Thoracic/tortuous/mild;Foreign Bodies/t...
#
#                                             Problems  \
# 0                                             normal
# 1  Calcified Granuloma;Nodule;Calcinosis;Calcinos...
# 2               Sutures;Cicatrix;Calcified Granuloma
# 3  Opacity;Foreign Bodies;Foreign Bodies;Foreign ...
# 4                     Aorta, Thoracic;Foreign Bodies
#
#                                                image  \
# 0           PA and LAT view CHEST XXXX, XXXX XXXX PM
# 1  Chest 2 views PA and lateral XXXX, XXXX XXXX a...
# 2             Chest radiographs, 2 XXXX and lateral
# 3                          CHEST 2V FRONTAL/LATERAL
# 4  PA and lateral chest x-XXXX dated XXXX, XXXX a...
#
#                                           indication  \
# 0                                   Positive TB test
# 1  Malignant neoplasm, evaluate for metastases/re...
# 2                    XXXX-year-old XXXX, chest pain.
# 3                                     Shielded, PDP.
# 4                XXXX-year-old XXXX with chest pain.
#
#                                           comparison  \
# 0                                              None.
# 1  Chest 2 views PA and lateral XXXX, XXXX p.m., ...
# 2                                        XXXX, XXXX.
# 3                                               XXXX
# 4                                              None.
#
#                                             findings  \
# 0  Heart size and vascularity normal. These conto...
# 1  Scattered calcified pulmonary nodules, XXXX re...
# 2  Sternotomy XXXX noted. Suture material overlie...
# 3  The heart is normal in size. The mediastinum i...
# 4  Heart size normal. Mild tortuosity of the thor...
#
#                                           impression  \
# 0                                      Normal chest.
# 1              No acute cardiopulmonary abnormality.
# 2                              No acute abnormality.
# 3  XXXX bullet fragments, as described above. No ...
# 4              No acute cardiopulmonary abnormality.
#
#                     filename projection  im_1  im_2               id  \
# 0  2349_IM-0914-2001.dcm.png    Lateral   914  2001  CXR2349_IM-0914
# 1  2949_IM-1348-1002.dcm.png    Lateral  1348  1002  CXR2949_IM-1348
# 2  2511_IM-1034-2001.dcm.png    Lateral  1034  2001  CXR2511_IM-1034
# 3  3363_IM-1616-1002.dcm.png    Lateral  1616  1002  CXR3363_IM-1616
# 4  2677_IM-1151-2001.dcm.png    Lateral  1151  2001  CXR2677_IM-1151
#
#                                           annotation  split  \
# 0  {'bone': '', 'heart': 'Heart size and vascular...  train
# 1  {'bone': '', 'heart': 'Heart size is normal.',...  train
# 2  {'bone': 'Sternotomy XXXX noted. Scarring left...  train
# 3  {'bone': 'Fragments overlying the posterior le...  train
# 4  {'bone': 'No acute bony abnormality.', 'heart'...  train
#
#                                      original_report  \
# 0  Heart size and vascularity normal. These conto...
# 1  Scattered calcified pulmonary nodules, XXXX re...
# 2  Sternotomy XXXX noted. Suture material overlie...
# 3  The heart is normal in size. The mediastinum i...
# 4  Heart size normal. Mild tortuosity of the thor...
#
#                                        annotations_1  \
# 0  {\n  "lung": "Lungs clear. No pleural effusion...
# 1  {\n  "lung": "Scattered calcified pulmonary no...
# 2  {\n  "lung": "Negative for focal pulmonary con...
# 3  {\n  "lung": "The lungs are grossly clear. XXX...
# 4  {\n  "lung": "There is no focal consolidation,...
#
#                                        annotations_2
# 0  {\n  "lung": "Lungs clear. No pleural effusion...
# 1  {\n  "lung": "Scattered calcified pulmonary no...
# 2  {\n  "lung": "Negative for focal pulmonary con...
# 3  {\n  "lung": "The lungs are grossly clear. XXX...
# 4  {\n  "lung": "There is no focal consolidation,...

# %%
IMAGES_DIR = '../data/images'

df = pd.read_csv(os.path.join(DATA_PATH, 'data_prep.csv'))
df['image_folder'] = df['filename'].apply(lambda x: 'CXR' + '-'.join(x.split('-')[:2]) )
#df['image_number'] = df['filename'].apply(lambda x: x.split('-')[-1].split('0')[0].split('.')[0] )
# TODO can't reconnect image specific to row
df['image_number'] = df.groupby('image_folder').cumcount().astype(str)
df['image_filename'] = df.apply(lambda x: os.path.join(IMAGES_DIR, x['image_folder'], x['image_number']+'.png'), axis=1 )

# %%
df['image_filename'].apply(lambda x: os.path.exists(x) ).sum()
# Out:
# np.int64(6066)

# %%
from pathlib import Path

sum(1 for _ in Path(IMAGES_DIR).rglob('*.png'))
# Out:
# 6067

# %%
df
# Out:
#        uid                                               MeSH  \
# 0        1                                             normal
# 1        1                                             normal
# 2        2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 3        2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 4        3                                             normal
# ...    ...                                                ...
# 7461  3997  Opacity/lung/upper lobe/right/round/small;Gran...
# 7462  3998                                             normal
# 7463  3998                                             normal
# 7464  3999                                             normal
# 7465  3999                                             normal
#
#                            Problems  \
# 0                            normal
# 1                            normal
# 2     Cardiomegaly;Pulmonary Artery
# 3     Cardiomegaly;Pulmonary Artery
# 4                            normal
# ...                             ...
# 7461              Opacity;Granuloma
# 7462                         normal
# 7463                         normal
# 7464                         normal
# 7465                         normal
#
#                                                   image  \
# 0                             Xray Chest PA and Lateral
# 1                             Xray Chest PA and Lateral
# 2                   Chest, 2 views, frontal and lateral
# 3                   Chest, 2 views, frontal and lateral
# 4                             Xray Chest PA and Lateral
# ...                                                 ...
# 7461                PA and lateral views of the chest.
# 7462   PA and lateral chest XXXX, XXXX XXXX comparis...
# 7463   PA and lateral chest XXXX, XXXX XXXX comparis...
# 7464              CHEST PA and LATERAL: on XXXX, XXXX.
# 7465              CHEST PA and LATERAL: on XXXX, XXXX.
#
#                                              indication  \
# 0                                      Positive TB test
# 1                                      Positive TB test
# 2                              Preop bariatric surgery.
# 3                              Preop bariatric surgery.
# 4     rib pain after a XXXX, XXXX XXXX steps this XX...
# ...                                                 ...
# 7461              XXXX-year-old male with positive PPD.
# 7462                          tuberculosis positive PPD
# 7463                          tuberculosis positive PPD
# 7464  This is a XXXX-year-old female patient with sh...
# 7465  This is a XXXX-year-old female patient with sh...
#
#                      comparison  \
# 0                         None.
# 1                         None.
# 2                         None.
# 3                         None.
# 4                           NaN
# ...                         ...
# 7461            None available.
# 7462                        NaN
# 7463                        NaN
# 7464  Chest x-XXXX, XXXX, XXXX.
# 7465  Chest x-XXXX, XXXX, XXXX.
#
#                                                findings  \
# 0     The cardiac silhouette and mediastinum size ar...
# 1     The cardiac silhouette and mediastinum size ar...
# 2     Borderline cardiomegaly. Midline sternotomy XX...
# 3     Borderline cardiomegaly. Midline sternotomy XX...
# 4                                                   NaN
# ...                                                 ...
# 7461  Heart size within normal limits. Small, nodula...
# 7462                                                NaN
# 7463                                                NaN
# 7464                                                NaN
# 7465                                                NaN
#
#                                              impression  \
# 0                                  Normal chest x-XXXX.
# 1                                  Normal chest x-XXXX.
# 2                          No acute pulmonary findings.
# 3                          No acute pulmonary findings.
# 4     No displaced rib fractures, pneumothorax, or p...
# ...                                                 ...
# 7461      No acute findings, no evidence for active TB.
# 7462      Heart size is normal and the lungs are clear.
# 7463      Heart size is normal and the lungs are clear.
# 7464  The cardiac silhouette is normal in size and c...
# 7465  The cardiac silhouette is normal in size and c...
#
#                        filename projection  im_1  im_2               id  \
# 0        1_IM-0001-4001.dcm.png    Frontal     1  4001   CXR1_1_IM-0001
# 1        1_IM-0001-3001.dcm.png    Lateral     1  3001   CXR1_1_IM-0001
# 2        2_IM-0652-1001.dcm.png    Frontal   652  1001     CXR2_IM-0652
# 3        2_IM-0652-2001.dcm.png    Lateral   652  2001     CXR2_IM-0652
# 4        3_IM-1384-1001.dcm.png    Frontal  1384  1001              NaN
# ...                         ...        ...   ...   ...              ...
# 7461  3997_IM-2048-1002.dcm.png    Lateral  2048  1002  CXR3997_IM-2048
# 7462  3998_IM-2048-1001.dcm.png    Frontal  2048  1001              NaN
# 7463  3998_IM-2048-1002.dcm.png    Lateral  2048  1002              NaN
# 7464  3999_IM-2049-1001.dcm.png    Frontal  2049  1001              NaN
# 7465  3999_IM-2049-2001.dcm.png    Lateral  2049  2001              NaN
#
#                                              annotation  split  \
# 0     {'bone': '', 'heart': 'Cardiac silhouette with...  train
# 1     {'bone': '', 'heart': 'Cardiac silhouette with...  train
# 2     {'bone': 'Midline sternotomy.', 'heart': 'Bord...   test
# 3     {'bone': 'Midline sternotomy.', 'heart': 'Bord...   test
# 4                                                   NaN    NaN
# ...                                                 ...    ...
# 7461  {'bone': '', 'heart': 'Heart size within norma...   test
# 7462                                                NaN    NaN
# 7463                                                NaN    NaN
# 7464                                                NaN    NaN
# 7465                                                NaN    NaN
#
#                                         original_report     image_folder  \
# 0     The cardiac silhouette and mediastinum size ar...     CXR1_IM-0001
# 1     The cardiac silhouette and mediastinum size ar...     CXR1_IM-0001
# 2     Borderline cardiomegaly. Midline sternotomy XX...     CXR2_IM-0652
# 3     Borderline cardiomegaly. Midline sternotomy XX...     CXR2_IM-0652
# 4                                                   NaN     CXR3_IM-1384
# ...                                                 ...              ...
# 7461  Heart size within normal limits. Small, nodula...  CXR3997_IM-2048
# 7462                                                NaN  CXR3998_IM-2048
# 7463                                                NaN  CXR3998_IM-2048
# 7464                                                NaN  CXR3999_IM-2049
# 7465                                                NaN  CXR3999_IM-2049
#
#      image_number                        image_filename
# 0               0     ../data/images/CXR1_IM-0001/0.png
# 1               1     ../data/images/CXR1_IM-0001/1.png
# 2               0     ../data/images/CXR2_IM-0652/0.png
# 3               1     ../data/images/CXR2_IM-0652/1.png
# 4               0     ../data/images/CXR3_IM-1384/0.png
# ...           ...                                   ...
# 7461            1  ../data/images/CXR3997_IM-2048/1.png
# 7462            0  ../data/images/CXR3998_IM-2048/0.png
# 7463            1  ../data/images/CXR3998_IM-2048/1.png
# 7464            0  ../data/images/CXR3999_IM-2049/0.png
# 7465            1  ../data/images/CXR3999_IM-2049/1.png
#
# [7466 rows x 19 columns]

# %%
IMAGES_DIR = '../data/images'
from PIL import Image

df = pd.read_csv(os.path.join(DATA_PATH, 'data_prep.csv'))

df = df[df['image_found']]

# %%
def load_images(image_filenames):
    """Load images from a directory."""
    images = []
    for filename in image_filenames:
        images.append(Image.open(filename))
    return images

# %%
load_images(df['image_filename'][:10])
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x624>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x420>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x624>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x624>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x621>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x621>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x624>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x624>]
